# %% [markdown]
# <a href="https://colab.research.google.com/github/krutika73/EDA-ON-PLAY-STORE-APP-REVIEW-ANALYSIS/blob/main/Krutika_Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - EDA PROJECT - PLAYSTORE APP REVIEW ANALYSIS

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member -**  Krutika Bhile

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The Google Play Store is a dominant and highly sought-after Android app store. As the official app hub for the Android operating system, it enables users to easily browse and download applications developed with the Android software development kit and published through Google. Its rich collection of data makes it an optimal source for generating sophisticated models. I have made an effort to conduct data analysis and predictions on the Google Play Store app dataset that I have acquired.
#
# The dataset includes 13 distinctive features that can be utilized to forecast the success of an app using various features. In addition to the Play Store data, user review data is also available and consists of 5 separate features.
#
# Our analysis process is divided into three distinct stages: Data Extraction, Data Cleaning, and Data Visualization.
#
# Initially, we gather the data from the website. Then, we undertake data cleaning on the dataset to minimize the error rate. After preparing the dataset, we conduct analysis using various plots and remove unnecessary information from the dataset. Lastly, we present the analysis results in a clear manner to illustrate the relationship among relevant factors. In the conclusion and solution to business objective section, we provide a comprehensive discussion of the practical implications and potential avenues for future research.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Developers create Android apps and release them on the Play Store. From a business or developer perspective, it's crucial to understand whether users are satisfied with the app or encountering any problems. To gain this insight, the Play Store has a Ratings and Reviews section for each app available on the store. Users can provide ratings and write reviews for a particular app. This process can be quite cumbersome, as it requires navigating to the Play Store to submit feedback or temporarily leaving the current app to open the Play Store app link using a URI. We never intended for our customers to leave our app, but this process forces us to redirect them to the Play Store.
#
# We believe that versatile app users consider online app reviews as a significant factor in deciding whether to purchase a paid app. It can be challenging for a potential user to sift through all the written comments and ratings to make a decision. Moreover, app developers have difficulty improving app performance based solely on overall ratings and would benefit from comprehending a large number of written remarks.
#
# 1.Which type of app is most prevalent on the Play Store?
#
# 2.What is the impact of an app's price on its rating?
#
# 3.What is the distribution of app prices?
#
# 4.What are some of the costliest apps available?
#
# 5.What type of apps are most commonly found in high-priced categories?
#
# 6.What impact does app size have on its rating?
#
# 7.What is the relationship between an app's price, size, and cost?
#
# 8.What is the minimum and maximum price for an app?
#
# 9.What is the average rating for apps?
#
# 10.What impact do reviews have on an app's rating?
#
# 11.Which category of apps has the highest number of reviews?
#
# 12.What is the most widely installed app category?
#
# 13.What categories of apps are most frequently downloaded from the Play Store?
#
# 14.Which apps have received the most reviews?
#
# 15.What is the sentiment polarity difference between paid and free apps?
#
# 16.What proportion of reviews have a positive, negative, or neutral sentiment?
#
# 17.Which category of apps have the most positive reviews?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# 1.	Improve app performance and user experience by identifying areas for improvement based on user feedback.
# 2.	Increase app ratings and positive reviews by addressing user complaints and suggestions.
# 3.	Enhance customer satisfaction by incorporating user feedback into the development process.
# 4.	Increase app downloads and revenue by improving app reputation through positive ratings and reviews.
# 5.	Gain a competitive advantage by staying ahead of industry trends and addressing user needs.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
from datetime import datetime
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing Play Store App Review Dataset
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Play Store Data.csv')

# %%
# Importing Play Store App Sentiment Data ## Customer Review Data
df2=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/User Reviews.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
# Dataset Rows & Columns count
print("Plya Store Dataset size")
print("Rows {} Columns {}".format(df.shape[0], df.shape[1]))
# Out:
# Plya Store Dataset size
# Rows 10841 Columns 13

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])
# Out:
# 483

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Visualizing the missing values
# Checking Null Value by plotting Heatmap
sns.heatmap(df.isnull(), cbar=False)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The objective is to evaluate the competitiveness in the Android marketplace by analyzing data on Play Store apps. The dataset comprises of 13 attributes, including some with missing values and object data types that need to be transformed into floating-point numbers.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **PLAYSTORE APP DATA**
#
# This file contains data on the Google Play applications. It has 10,841 rows of data with the following columns:
#
# App Category: Category of the app. This could be beauty, business, entertainment, education...etc.
#
# Rating: How users rate the app out of 5, with 1 being the lowest rating and 5 being the highest.
#
# Reviews: The number of user reviews each app has received.
#
# Size: The memory size needed to install the application.
#
# Installs: The number of times each application has been installed by users.
#
# Type: Whether the app is free or a paid app.
#
# Price: The price of the app.
#
# Content Rating: This column specifies the intended audience for the app. Can be for teens, mature audience, or everyone.
#
# Genres: The sub-category for each app. Example: for the Education category, this could be Education: Pretend Play, for example.
#
# Last Updated: Release date of the most recent update for the app.
#
# Current Ver: The app's current version.
#
# Android Ver: The oldest version of Android OS supported by the app.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),".")
# Out:
# No. of unique values in  App is 9660 .
# No. of unique values in  Category is 34 .
# No. of unique values in  Rating is 40 .
# No. of unique values in  Reviews is 6002 .
# No. of unique values in  Size is 462 .
# No. of unique values in  Installs is 22 .
# No. of unique values in  Type is 3 .
# No. of unique values in  Price is 93 .
# No. of unique values in  Content Rating is 6 .
# No. of unique values in  Genres is 120 .
# No. of unique values in  Last Updated is 1378 .
# No. of unique values in  Current Ver is 2832 .
# No. of unique values in  Android Ver is 33 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %% [markdown]
# **CLEANING THE DATA**

# %% [markdown]
# **A) CHECKING DATATYPE**

# %%
print("Columns and data types")
pd.DataFrame(df.dtypes).rename(columns = {0:'dtype'})
# Out:
# Columns and data types
#                   dtype
# App              object
# Category         object
# Rating          float64
# Reviews          object
# Size             object
# Installs         object
# Type             object
# Price            object
# Content Rating   object
# Genres           object
# Last Updated     object
# Current Ver      object
# Android Ver      object

# %% [markdown]
# **1) REVIEWS**

# %%
df["Reviews"].value_counts()
# Out:
# 0         596
# 1         272
# 2         214
# 3         175
# 4         137
#          ...
# 342912      1
# 4272        1
# 5517        1
# 4057        1
# 398307      1
# Name: Reviews, Length: 6002, dtype: int64

# %%
reviews = [i for i in df['Reviews']]
def cleaning_review_data(Reviews_list):
  '''
  This Function Converts DataType From Object To Float
  '''
  cleaned_data = []
  for review in Reviews_list:
     if 'M' in review:
       review = review.replace('M','')
       review = float(review)*1000000
     cleaned_data.append(review)
  return cleaned_data     

df['Reviews']=cleaning_review_data(reviews)
df['Reviews']=df['Reviews'].astype(float)   
df['Reviews'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# **2) SIZE**

# %%
df["Size"].value_counts()
# Out:
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 429k                     1
# 200k                     1
# 460k                     1
# 728k                     1
# 619k                     1
# Name: Size, Length: 462, dtype: int64

# %%
newSize = []
for row in df.Size:
    newrow = row[:-1]
    try:
        newSize.append(float(newrow))
    except:
        newSize.append(0) 
    
df.Size = newSize          #Sizes of applications are converted from string to integer format
df['Size'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# **3) INSTALLS**

# %%
df["Installs"].value_counts()
# Out:
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             907
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Free                 1
# Name: Installs, dtype: int64

# %%
df['Installs'] = df.Installs.str.replace(",","")
df['Installs'] = df.Installs.str.replace("+","")
df['Installs'] = df.Installs.replace("Free",np.nan)
df['Installs'] = df['Installs'].astype(float)
df['Installs'].dtype
# Out:
# <ipython-input-23-b9a734f657b2>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Installs'] = df.Installs.str.replace("+","")
# dtype('float64')

# %% [markdown]
# **4) PRICE**

# %%
df["Price"].value_counts().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0         10040
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $1.75         1
# $14.00        1
# $4.85         1
# $46.99        1
# $1.04         1
# Name: Price, Length: 93, dtype: int64>

# %%
df['Price'] = df.Price.replace("Everyone",np.nan)
df['Price'] = df.Price.str.replace("$","").astype(float)
df['Price'].dtype
# Out:
# <ipython-input-25-3d0a5f3d130b>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price'] = df.Price.str.replace("$","").astype(float)
# dtype('float64')

# %%
df.describe()
# Out:
#             Rating       Reviews          Size      Installs         Price
# count  9367.000000  1.084100e+04  10841.000000  1.084000e+04  10840.000000
# mean      4.193338  4.443887e+05     31.241500  1.546434e+07      1.027368
# std       0.537431  2.927728e+06     91.801512  8.502936e+07     15.949703
# min       1.000000  0.000000e+00      0.000000  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01      3.100000  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03     10.000000  1.000000e+05      0.000000
# 75%       4.500000  5.479800e+04     28.000000  5.000000e+06      0.000000
# max      19.000000  7.815831e+07   1020.000000  1.000000e+09    400.000000

# %% [markdown]
# **B) HANDLING NULL VALUES**

# %%
table=pd.DataFrame(index=df.columns)
table["datatype"]=df.dtypes
table["not null values"]=df.count()
table["null value"]=df.isnull().sum()
 # table["% of the null value"]=df.isnull().mean()
 # table["unique count"]=df.nunique()
table
# Out:
#                datatype  not null values  null value
# App              object            10841           0
# Category         object            10841           0
# Rating          float64             9367        1474
# Reviews         float64            10841           0
# Size            float64            10841           0
# Installs        float64            10840           1
# Type             object            10840           1
# Price           float64            10840           1
# Content Rating   object            10840           1
# Genres           object            10841           0
# Last Updated     object            10841           0
# Current Ver      object            10833           8
# Android Ver      object            10838           3

# %% [markdown]
# **1) RATING**

# %%
df[df['Rating'].isnull()]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#        Reviews  Size  Installs  Type  Price Content Rating  \
# ...

# %%
# The "Rating" column has 1474 rows with null values. 
# To handle this, instead of dropping the rows, we will replace the null values with the median of the available values.

df['Rating'].fillna(value=df['Rating'].median(),inplace=True)

# %%
# Verifying the results with a cross-check.

df['Rating'].isnull().sum()
# Out:
# 0

# %%
# Sanity Check

# A sanity check was performed to ensure that the number of ratings was not greater than the number of installations. 
# As only those who have installed the app can provide a rating.

# %%
df.loc[df['Rating'] > df['Installs']]
# Out:
#                                                      App           Category  \
# 649                          Healthy Relationships Guide             DATING
# 652                                              PlusOne             DATING
# 2422                                           Visualmed            MEDICAL
# 2425   Be the Expert in Phlebotomy - Professional Nur...            MEDICAL
# 2454                                 KBA-EZ Health Guide            MEDICAL
# ...                                                  ...                ...
# 10701                                          F-O-Meter             FAMILY
# 10708                                        Custos F.O.           BUSINESS
# 10745                                            FP Boss            FINANCE
# 10764                                  FP Transportation  AUTO_AND_VEHICLES
# 10775                                 FQ - Football Quiz             SPORTS
#
# ...

# %%
# Removing the values that failed the sanity check.

temp_data = df.loc[df['Rating'] > df['Installs']].index
df.drop(labels=temp_data,inplace=True)

# %%
# Verifying the results with a cross-check.

df.loc[df['Rating'] > df['Installs']]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# **2) TYPE**

# %%
df["Type"].value_counts()
# Out:
# Free    9989
# Paid     769
# 0          1
# Name: Type, dtype: int64

# %%
# The data includes two types of applications: free and paid. 
# In one row, the type is recorded as "nan" and the price is 0, indicating that it is a free app. 
# To handle this, the "nan" value was changed to "free."

df['Type'].fillna('Free',inplace=True)

# %%
# Verifying the results with a cross-check.

df['Type'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **3) CONTENT RATING**

# %%
df["Content Rating"].value_counts()
# Out:
# Everyone           8641
# Teen               1203
# Mature 17+          496
# Everyone 10+        413
# Adults only 18+       3
# Unrated               2
# Name: Content Rating, dtype: int64

# %%
df[df['Content Rating'].isnull()]
# Out:
#                                            App Category  Rating    Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0  3000000.0
#
#        Size  Installs Type  Price Content Rating             Genres  \
# 10472   0.0       NaN    0    NaN            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# In some columns, the values are found to be mismatched. 
# To handle this, we will drop the entire row.

df.drop(10472, axis=0)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# **4) CURRENT VERSION**

# %%
df[df['Current Ver'].isnull()]
# Out:
#                                    App             Category  Rating  Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2     55.0
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1  20145.0
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2   4010.0
# 6803                         BT Master               FAMILY     4.3      0.0
# 7333                       Dots puzzle               FAMILY     4.0    179.0
# 7407                   Calculate My IQ               FAMILY     4.3     44.0
# 7730                            UFO-CQ                TOOLS     4.3      1.0
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     4.3      8.0
#
#         Size   Installs  Type  Price Content Rating             Genres  \
# 15       2.7     5000.0  Free   0.00       Everyone       Art & Design
# 1553    11.0  1000000.0  Free   0.00       Everyone   Libraries & Demo
# ...

# %%
df['Current Ver'].value_counts()
# Out:
# Varies with device    1456
# 1.0                    786
# 1.1                    258
# 1.2                    177
# 2.0                    150
#                       ...
# 7.16.8                   1
# 5.1.0 free               1
# 2.10.06                  1
# 18.0.2                   1
# 2.0.148.0                1
# Name: Current Ver, Length: 2826, dtype: int64

# %%
# The data has no specific value to replace null entries with. 
# Therefore, we will drop the 8 rows containing null values.

df=df[df['Current Ver'].notna()]
df.shape
# Out:
# (10751, 13)

# %% [markdown]
# **5) ANDROID VERSION**

# %%
df[df['Android Ver'].isnull()]
# Out:
#                                            App         Category  Rating  \
# 4453                    [substratum] Vacuum: P  PERSONALIZATION     4.4
# 4490                      Pi Dark [substratum]  PERSONALIZATION     4.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
#
#          Reviews  Size  Installs  Type  Price Content Rating  \
# 4453       230.0  11.0    1000.0  Paid   1.49       Everyone
# 4490       189.0   2.1   10000.0  Free   0.00       Everyone
# 10472  3000000.0   0.0       NaN     0    NaN            NaN
#
#                   Genres    Last Updated Current Ver Android Ver
# 4453     Personalization   July 20, 2018         4.4         NaN
# 4490     Personalization  March 27, 2018         1.1         NaN
# 10472  February 11, 2018          1.0.19  4.0 and up         NaN

# %%
df['Android Ver'].value_counts()
# Out:
# 4.1 and up            2427
# 4.0.3 and up          1487
# 4.0 and up            1360
# Varies with device    1359
# 4.4 and up             975
# 2.3 and up             647
# 5.0 and up             598
# 4.2 and up             387
# 2.3.3 and up           281
# 2.2 and up             244
# 4.3 and up             242
# 3.0 and up             237
# 2.1 and up             132
# 1.6 and up             113
# 6.0 and up              59
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              31
# 5.1 and up              24
# 1.5 and up              19
# 4.4W and up             12
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               5
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %%
# There is no specific value to replace null entries with. 
# Hence, we will drop the three rows containing null values.

df=df[df['Android Ver'].notna()]
df.shape
# Out:
# (10748, 13)

# %%
# A cross-check is performed to ensure that no remaining null values exist in the data.

table=pd.DataFrame(index=df.columns)
table["datatype"]=df.dtypes
table["not null values"]=df.count()
table["null value"]=df.isnull().sum()

table
# Out:
#                datatype  not null values  null value
# App              object            10748           0
# Category         object            10748           0
# Rating          float64            10748           0
# Reviews         float64            10748           0
# Size            float64            10748           0
# Installs        float64            10748           0
# Type             object            10748           0
# Price           float64            10748           0
# Content Rating   object            10748           0
# Genres           object            10748           0
# Last Updated     object            10748           0
# Current Ver      object            10748           0
# Android Ver      object            10748           0

# %% [markdown]
# ### What all manipulations have you done and insights you found?
# We started by verifying the data type and converting it to float. Next, we performed a sanity check to ensure the number of reviews was not higher than the number of installed user. Finally ,we checked for null values and replaced them with valid values.The null values in the Rating column have been replaced with the median value.Where replacement is not possible (content ratings,current version,and Android version),the null values have been deleted.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
#  #### Chart - 1 Application Type (Univariate Analysis)

# %%
# Chart - 1 visualization code
Type_distribution = df['Type'].value_counts()
Type_distribution.plot(kind='bar', color='orange')
plt.title('Type of Distribution ')
plt.ylabel('Number of Apps')
plt.xlabel('Type')
# Out:
# Text(0.5, 0, 'Type')

# %%
(values,counts)= np.unique(df["Type"], return_counts=True)
print(counts)
for index in range(len(values)):
    print(f"{values[index]}: {counts[index]}")
# Out:
# [9982  766]
# Free: 9982
# Paid: 766

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# A bar graph is a useful tool for comparing the differences between the free and paid categories in terms of size, quantity, or frequency of data. It presents the data visually in a simple and straightforward manner, making it easier to understand the comparison and differences between the two categories.
#
# As we're aware, there are only two categories of applications, free and paid. In this case, a bar chart is an effective tool for comparing these two categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Typically, the amount of downloads for paid applications is fewer in comparison to those for free applications.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Given the prevalence of free apps on the app store, consumers may have formed an expectation that apps should be free to download and utilize. Thus, it may be necessary to implement alternative revenue-generating methods, such as in-app purchases, subscriptions, or advertisements.
#
# One option could be to offer a free version of the app with limited capabilities, and then allow users to purchase additional features or functionality through in-app purchases or subscriptions.

# %% [markdown]
# #### Chart - 2  Price and Rating (Bivariate Analysis)

# %%
# Chart - 2 visualization code
rcParams['figure.figsize'] = 11,8.5

sns.jointplot(x='Price', y='Rating', data=df, kind='reg')
plt.show()

# ======================
df["Price"].hist()
plt.title("Pricing Distribution For Apps")
plt.ylabel("App Count")
plt.xlabel("Price (U.S $)")
# Out:
# Text(0.5, 0, 'Price (U.S $)')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Our objective was to examine the correlation between price and ratings, and a joint plot serves as a useful tool in visualizing this relationship between two variables within a dataset. It enables us to view both the distribution and correlation of the two variables simultaneously.
#
# As histograms provide an effortless means of comprehending the underlying distribution of a dataset, we selected to use a histogram to achieve our goal.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the analysis of the graphs, we can deduce that as the price increases, the rating remains relatively constant at a value greater than 4.
#
# The majority of the highly rated apps have a price range of approximately 1 to 30 dollars.
#
# But what shocking is the Apps priced above 250$ !!!

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# One way to determine the ideal price for your app is to examine the correlation between pricing and ratings. If you observe that apps with a higher price tag tend to have better ratings, it might be worth considering setting a premium price for your app.
#
# One monetization option to consider, if you discover that apps with higher prices usually receive better ratings, is incorporating in-app purchases or subscriptions. This approach can boost your revenue while still allowing you to maintain a high-quality app and a higher price point.

# %% [markdown]
# #### Chart - 3 Most Installed and Expensive App (Bivariate Analysis)

# %%
# Chart - 3 visualization code
expensive_apps = df.loc[df['Price'] >=250]

expensive_apps.loc[:, ["App", "Category"]]
# Out:
#                                  App   Category
# 4197          most expensive app (H)     FAMILY
# 4362                      💎 I'm rich  LIFESTYLE
# 4367        I'm Rich - Trump Edition  LIFESTYLE
# 5351                       I am rich  LIFESTYLE
# 5354                  I am Rich Plus     FAMILY
# 5355                   I am rich VIP  LIFESTYLE
# 5356               I Am Rich Premium    FINANCE
# 5357             I am extremely Rich  LIFESTYLE
# 5358                      I am Rich!    FINANCE
# 5359              I am rich(premium)    FINANCE
# 5362                   I Am Rich Pro     FAMILY
# 5364  I am rich (Most expensive app)    FINANCE
# 5366                       I Am Rich     FAMILY
# 5369                       I am Rich    FINANCE
# 5373              I AM RICH PRO PLUS    FINANCE

# %%
expensive_apps["Installs"].groupby(expensive_apps["App"]).sum()
# Out:
# App
# I AM RICH PRO PLUS                  1000.0
# I Am Rich                          10000.0
# I Am Rich Premium                  50000.0
# I Am Rich Pro                       5000.0
# I am Rich                           5000.0
# I am Rich Plus                     10000.0
# I am Rich!                          1000.0
# I am extremely Rich                 1000.0
# I am rich                         100000.0
# I am rich (Most expensive app)      1000.0
# I am rich VIP                      10000.0
# I am rich(premium)                  5000.0
# I'm Rich - Trump Edition           10000.0
# most expensive app (H)               100.0
# 💎 I'm rich                         10000.0
# Name: Installs, dtype: float64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To swiftly investigate apps priced above 250$, one can quickly examine them.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Of the most costly apps, the most widely installed is "I am Rich," which is the most popular among them.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Gleaning insights from the top installed apps can give you a better understanding of the app preferences among users. This understanding can then be leveraged to guide the creation of your own app and uncover market gaps that your app could fill.
#
# By aligning your app with the popular ones, you enhance its visibility and user appeal.

# %% [markdown]
# #### Chart - 4 Category Vs Price (Bivariate Analysis)

# %%
# Chart - 4 visualization code
sns.scatterplot(x="Category", y="Price",data=df, color='green')

plt.xticks(rotation=90)
plt.figure(figsize=(14,9))
plt.rcParams['figure.figsize'] = 11,8.5

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We were interested in identifying which category the most expensive apps belong to.
# Scatter plots can be especially helpful in detecting outliers within a dataset, as they allow you to easily spot data points that deviate significantly from the overall pattern.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Ignoring the catogories with price > 100$
#
# Medical and Family apps are the most expensive. Some medical apps extend even upto 80$.
#
# All other apps are priced under 30$.
#
# Shocking..... all game apps are reasonably priced below 20$.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# To position your medical app as a top-quality product that delivers exceptional value, pricing it at a premium level may be a more effective strategy. By creating a distinctive app that offers features and functionality that set it apart from competitors, you can justify a higher price point and capture the attention of discerning customers.

# %% [markdown]
# #### Chart - 5 Size Vs Rating (Bivariate Analysis)

# %%
# Chart - 5 visualization code
#app distribution according to size rating and type
plt.figure(figsize=(12,6))
sns.scatterplot(df['Size'],
                df['Rating'],
                hue=df['Type'],
                s=100)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plots provide a useful way to examine the relationship between two variables and detect any underlying patterns or trends, including positive or negative correlations. Additionally, they are an effective tool for identifying outliers or anomalies in the data that might not be easily discernible with other types of plots, making it easier to spot any unusual trends or patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# While there is generally a positive correlation between the size and rating of an app, this relationship is not always straightforward. For example, some apps may have a high rating despite having a relatively small or large size. However, by analyzing the data, we can see that the majority of top-rated apps fall within a specific size range, which suggests that there may be an optimal size for maximizing an app's popularity.
#
# When it comes to app ratings, size is not always the most important factor. In fact, many top-rated apps have a rating of 3 or higher regardless of their size. However, upon closer examination, it appears that most of the highest-rated apps tend to fall within a certain size range of roughly 2MB to 40MB, indicating that there may be an ideal size that appeals to a wide range of users.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By analyzing the relationship between app size and rating, you can develop a more streamlined and efficient design that prioritizes the features that are most valuable to users. This can help you create a more highly rated app while keeping its size manageable, ensuring that users can easily download and use it on their devices.
#
# One way to leverage this information is by pricing your app based on its size, with smaller apps being offered at a lower price point. Given that smaller apps often tend to have higher ratings, this pricing strategy may appeal to users who are looking for a high-quality app that doesn't take up too much space on their device.

# %% [markdown]
# #### Chart - 6 Size Vs Rating For Paid Apps (Multivariate Analysis)

# %%
# Chart - 6 visualization code
paid_apps = df[df['Price'] > 0]

# %%
g = sns.JointGrid(data=paid_apps, x="Rating", y="Size", space=0, ratio=17)
sns.set_theme(style="white", color_codes=True)

g.plot_joint(sns.scatterplot, size=paid_apps["Rating"], sizes=(30, 120),
             color="g", alpha=.6, legend=False)
g.plot_marginals(sns.rugplot, height=1, color="g", alpha=.6)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:1740: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   f.tight_layout()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A joint grid in Python is a graphical tool designed to help you visualize how two variables are related. By combining a scatter plot and a histogram, it enables you to simultaneously explore the distribution of each variable along the x and y-axes, respectively. This approach can help reveal any underlying patterns or trends in the data that might not be apparent when examining the variables separately.
# A joint grid in Python is preferred when we need to examine the relationship between two variables as well as their individual distributions. The scatter plot component of the joint grid illustrates the relationship between the variables, while the histograms on either side depict the distribution of each variable separately. This approach can be particularly helpful in identifying any hidden patterns or trends in the data that might be difficult to discern by simply studying a scatter plot or histogram in isolation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most highly rated paid apps have relatively small sizes, indicating that they are typically designed to deliver specific functionalities without being overly burdensome. This suggests that users generally favor paid apps that are lightweight and easy to manage, as heavier ones may struggle to gain traction in the market.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Using this information, you can streamline the size of your app by prioritizing the features that matter most to your users while eliminating extraneous ones. By doing so, you may be able to enhance the rating of your app while still ensuring that it remains a manageable size.
#
# To attract users who prefer smaller apps, consider incorporating keywords associated with compact size into your app's title and description. This can help increase the visibility of your app to users who prioritize lightweight, easy-to-use applications.

# %% [markdown]
# #### Chart - 7 Min Price App (Univariate Analysis)

# %%
# Chart - 7 visualization code
print("$ {}".format(paid_apps["Price"].min()))
# Out:
# $ 0.99

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To determine the minimum price for paid apps, one would need to check.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The minimum price for paid apps has been found to be 0.99$.

# %% [markdown]
# Chart - 8 Rating (Univariate Analysis)

# %%
# Chart - 8 visualization code
plt.figure(figsize=(10,5))
sns.countplot(x='Rating',data=df)
plt.title('RATING DISTRIBUTION')
plt.ylabel('Number of Apps')
plt.xticks(rotation=90)
plt.xlabel('Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count plots are a useful tool for visualizing the distribution and frequency of unique categories or values within a categorical dataset. These plots can assist in pinpointing the most prevalent categories or values present within the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most apps have been rated between three to five stars, with the highest rating being 4.3 stars.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Analyzing the ratings of your competitors' apps can provide valuable insights to adjust your strategy. Additionally, you can examine the reviews and identify common reasons why users have assigned specific ratings to your app.

# %% [markdown]
# #### Chart - 9 REVIEWS PER RATING (Bivariate Analysis)

# %%
# Chart - 9 visualization 
rating_df = df.groupby('Rating').sum().reset_index()
print(f"Average Rating {df['Rating'].mean()}")
plt.figure(figsize=(10,5))
plt.plot(rating_df['Rating'],rating_df['Reviews'])
plt.title('REVIEW PER RATING')
plt.ylabel('Reviews')
plt.xlabel('Rating')
# Out:
# Average Rating 4.2056103461109045
# Text(0.5, 0, 'Rating')

# %%
print(f"Average Rating {df['Rating'].mean()}")
# Out:
# Average Rating 4.2056103461109045

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize changes in review data based on rating, a simple line graph is an effective choice. By using a line graph, you can easily identify trends in the data, such as upward or downward patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A correlation may exist between a high app rating and a large number of reviews, or conversely, a low rating and a small number of reviews. Typically, most apps tend to perform well with an average rating of 4.2 or above, accompanied by a high number of reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Leverage data analysis to enhance your competitive analysis. For instance, if you observe that highly rated apps tend to have a significant number of reviews, it may be advantageous to prioritize acquiring more reviews for your app in order to boost its rating.

# %% [markdown]
# #### Chart - 10 Category and Reviews (Bivariate Analysis)

# %%
# Chart - 10 visualization 
category_list = list(df['Category'].unique())
category_review = []
for i in category_list:
    x = df[df['Category'] == i]
    if(len(x)!=0):
        review = sum(x.Reviews)/len(x)
        category_review.append(review)
    else:
        review = sum(x.Reviews)
        category_review.append(review)
#sorting
df_category_reviews = pd.DataFrame({'category': category_list,'review':category_review})
new_index = (df_category_reviews['review'].sort_values(ascending=False)).index.values
sorted_df =df_category_reviews.reindex(new_index)

# visualization
plt.figure(figsize=(15,10))
sns.barplot(x=sorted_df['category'], y=sorted_df['review'])
plt.xticks(rotation=80)
plt.xlabel("Category")
plt.ylabel("Reviews")
plt.title("Category and Reviews")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Our objective is to display the distribution of data that falls within discrete categories.
#
# Bar plots are a frequently employed tool for visualizing data that is divided into distinct categories. This type of plot is useful for representing the number of apps in different category groups, the number of reviews in distinct categories, and other similar types of data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The categories with the highest number of reviews are Social and Communication, followed by Games, Photography, and Video Players.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Examining the number of reviews per category can help a business pinpoint the most popular app categories among users. This insight can be leveraged to make informed decisions about which app categories to develop or invest in, with the goal of reaching a broader audience.
#
# Review analysis can help a business identify areas of concern within their app, such as bugs, usability issues, or missing features. By addressing these issues, a business can potentially generate more positive reviews and higher ratings, resulting in increased downloads and revenue.

# %% [markdown]
# #### Chart - 11 Category and Installs (Bivariate Analysis)

# %%
# Chart - 11 visualization code
category_list = list(df['Category'].unique())
category_install = []
for i in category_list:
    x = df[df['Category'] == i]
    if(len(x)!=0):
        install = sum(x.Installs)/len(x)
        category_install.append(install)
    else:
        install = sum(x.Installs)
        category_install.append(install)
        
#sorting
df_category_install = pd.DataFrame({'category': category_list,'install':category_install})
new_index = (df_category_install['install'].sort_values(ascending=False)).index.values
sorted_df =df_category_install.reindex(new_index)

# visualization
plt.figure(figsize=(15,10))
sns.barplot(x=sorted_df['category'], y=sorted_df['install'])
plt.xticks(rotation=80)
plt.xlabel("Category")
plt.ylabel("Install")
plt.title("Category and Install")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize the contribution of different sub-categories to the total value, we will create a stacked bar chart.In this case, we wanted to compare the relative magnitudes (Installations) of different values (Category), so we used a bar graph.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, it is apparent that the Communication category has the highest number of downloads, followed by Social and Video Players.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# A business can determine trends in app usage and popularity by analyzing installs per category.Using this information, you can predict future trends and make informed product development and marketing decisions.Businesses can identify problems with their apps by analyzing the installs, such as low retention rates, low conversion rates, or poor user experiences.More installs and revenue can be generated by addressing these issues.

# %% [markdown]
# #### Chart - 12 Content Rating (Univariate Analysis)

# %%
# Chart - 12 visualization code
plt.figure(figsize=(10,7))
sns.countplot(data=df, x='Content Rating')
plt.xticks(rotation=80)
plt.title('Content Rating',color = 'green',fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In categorical data sets, count plots are used to visualize the frequency of unique values.The most common values or categories in the data can be identified with their help.As a result, we use a count plot to quickly visualize the distribution of a categorical variable (Content rating).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As depicted in the bar chart, apps with the "Everyone" content rating make up the majority, followed by those with a "Teen" rating.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By examining the content rating of apps, a business can develop marketing campaigns that are tailored to specific age groups or audiences, which can increase the likelihood of success.
#
# Through the analysis of an app's content rating, a business can customize its marketing efforts to address specific age groups or target audiences, ultimately enhancing the probability of success.

# %% [markdown]
# #### Chart - 13 Category (Univariate Analysis)

# %%
# Chart - 13 visualization code
temp = df['Category'].value_counts().reset_index()
plt.figure(figsize=(12,12))
ax = plt.subplot(111)
plt.pie(x = temp['Category'], labels= temp['index'],autopct= '%1.1f%%')
plt.legend()
ax.legend(bbox_to_anchor=(1.4, 1))
plt.show()

# %%
top = np.array(df.Category.value_counts().reset_index()['index'])
print('Most occuring categories are \n',top[:6])
# Out:
# Most occuring categories are
#  ['FAMILY' 'GAME' 'TOOLS' 'MEDICAL' 'BUSINESS' 'PRODUCTIVITY']

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To illustrate the hierarchical relationships of categorical data originating from different regions, we found it helpful to use a pie chart that depicts the relative proportions of each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# While Family and Game apps remain dominant, there is a growing interest in Tools, Business, and Medical apps, which are steadily gaining traction in the market.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By gaining insight into popular app categories on the Play Store, a business can pinpoint potential markets for its own app. For instance, if a business observes a surge in demand for family and game apps, it might decide to create a productivity app that caters to that particular market.
#
# This information can enable a business to recognize areas of opportunity in the market and create apps that address those areas.

# %% [markdown]
# #### Chart - 14 -  Most occuring categories Rating (Bivariate Analysis)

# %%
# Correlation Heatmap visualization code
plt.figure(figsize= (15,10))
plt.suptitle("Ratings of Different Categories",fontsize = 25)

plt.subplot(2,3,1)
sns.kdeplot(df[df['Category'] == 'FAMILY']['Rating'],color='blue',shade=True )
plt.title('Rating of FAMILY Apps')

plt.subplot(2,3,2)
sns.kdeplot(df[df['Category'] == 'GAME']['Rating'],color='blue',shade=True)
plt.title('Rating of GAME Apps')


plt.subplot(2,3,3)
sns.kdeplot(df[df['Category'] == 'TOOLS']['Rating'],color='blue',shade=True)
plt.title('Rating of TOOLS Apps')


plt.subplot(2,3,4)
sns.kdeplot(df[df['Category'] == 'MEDICAL']['Rating'],color='blue',shade=True)
plt.title('Rating of MEDICAL Apps')


plt.subplot(2,3,5)
sns.kdeplot(df[df['Category'] == 'BUSINESS']['Rating'],color='blue',shade=True)
plt.title('Rating of BUSINESS Apps')


plt.subplot(2,3,6)
sns.kdeplot(df[df['Category'] == 'PRODUCTIVITY']['Rating'],color='blue',shade=True)
plt.title('Rating of PRODUCTIVITY Apps')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Kernel Density Estimate (KDE) plot
#
# A KDE plot is a smoothed version of a histogram, which is used to visualize the probability density function of a continuous variable.
#
# So we choose this seaborn KDE plot, here the function takes in a data set of rating of most occuring categories and creates a plot of the estimated probability density of the data. I

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The above Kernel Density Estimate (KDE) plot suggests that the categories 'Family', 'Game', 'Tools', 'Medical', 'Business', and 'Productivity' have almost identical ratings of 4.0 - 4.7.

# %% [markdown]
# ##### 3.Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Analyzing the most frequently used and top-rated categories on the Play Store can provide valuable intelligence to a business about its competitors. By leveraging this information, a business can identify potential partners, such as other app developers or companies offering complementary products, that can help it strengthen its market position.

# %% [markdown]
# #### Chart - 15 - Reviews Vs Rating (Bivariate Analysis)

# %%
# Pair Plot visualization code
print("Number of Apps with more than 1M reviews",df[df['Reviews'] > 1000000].shape[0])
print("\nTop 20 apps with most reviews: \n",df[df['Reviews'] > 1000000].sort_values(by = 'Reviews', ascending = False).head(20)['App'])
# Out:
# Number of Apps with more than 1M reviews 704
#
# Top 20 apps with most reviews:
#  2544                                    Facebook
# 3943                                    Facebook
# 336                           WhatsApp Messenger
# 381                           WhatsApp Messenger
# 3904                          WhatsApp Messenger
# 2604                                   Instagram
# 2611                                   Instagram
# 2545                                   Instagram
# 3909                                   Instagram
# 382     Messenger – Text and Video Chat for Free
# 4104    Messenger – Text and Video Chat for Free
# 335     Messenger – Text and Video Chat for Free
# 1879                              Clash of Clans
# 1704                              Clash of Clans
# 1670                              Clash of Clans
# 3986                              Clash of Clans
# 4005     Clean Master- Space Cleaner & Antivirus
# ...

# %%
print('for all apsps more tahn 1M reviews')
sns.jointplot(x='Reviews',y='Rating',data =df[df['Reviews']>100000],color='darkred')
plt.show()

print('for apps below 1M reviews')
sns.jointplot(x='Reviews',y='Rating',data =df[df['Reviews']<100000],color ='darkblue')
plt.show()
# Out:
# for all apsps more tahn 1M reviews
# for apps below 1M reviews

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Our goal was to explore the connection between reviews and ratings, and we found that a joint plot is a powerful tool for simultaneously visualizing the distribution and relationship between two variables in a dataset. Using a joint plot can be helpful when seeking to understand the correlation between two variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It is probable that apps with the highest number of reviews also have higher ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Positive reviews and high ratings can be leveraged in marketing efforts to entice new users and enhance an app's visibility on the Play Store.
#
# A business can also pinpoint users who leave favorable reviews and high ratings, as these individuals may be valuable influencers capable of promoting the app to a wider audience.

# %% [markdown]
# ### Chart - 16 Price Distribution (Univariate Analysis)

# %%
# Chart - 16 visualization code
plt.figure(figsize=(10,7))
sns.kdeplot(df[df['Type'] == 'Paid']['Price'], color = 'blue', shade = True)
plt.xlabel('Prices of Apps')
plt.title('Pricing Distribution of Paid Apps')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Kernel Density Estimation (KDE) plots in Python are useful when working with univariate datasets and aiming to display the distribution of the data, particularly when the data possesses a complex or non-standard distribution, when working with small datasets, when comparing multiple datasets, or when matching a dataset to a known distribution, or when identifying outliers in the data. In this case, we used the KDE plot to visualize the density distribution of the price of the app, which is a univariate dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It is worth mentioning that the majority of paid apps are priced reasonably.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# By examining the density distribution of app prices, a business can gain an understanding of the typical price range for apps within their desired category. This information can be used to establish a pricing strategy that is competitive within the market.

# %% [markdown]
# ## Chart - 17 - Correlation Heatmap

# %%
#Chart - 17 - Correlation Heatmap
df.corr()
# Out:
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.063494 -0.026061  0.045865 -0.022472
# Reviews   0.063494  1.000000 -0.005350  0.643040 -0.009202
# Size     -0.026061 -0.005350  1.000000 -0.026114  0.020948
# Installs  0.045865  0.643040 -0.026114  1.000000 -0.011140
# Price    -0.022472 -0.009202  0.020948 -0.011140  1.000000

# %%
f,ax = plt.subplots(figsize=(12, 12))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax,cmap="Blues")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# When working with multiple variables, a correlation heatmap can be advantageous for visualizing the relationship between them in a single plot. By utilizing a correlation heatmap, it is straightforward to determine which variables are strongly correlated and which are not.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a small negative correlation between the price of an app and its rating, number of reviews, and installs. This implies that when the price of an app increases, there is a slight decrease in the average rating, total number of reviews, and installs.
#
# There is a small positive correlation between the app rating and its number of installs and reviews. This suggests that as the average user rating increases, the number of app installs and reviews also tend to increase.

# %% [markdown]
# ## Chart - 18 - Pair Plot

# %%
# Pair Plot visualization code
# Create the pair plot
sns.pairplot(df)

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pairplot function generates a matrix of scatter plots for all the numeric variables in a DataFrame, with histograms plotted along the diagonal. It is a useful visualization tool for analyzing the relationships among multiple variables in a dataset. Each cell in the matrix represents the relationship between two variables, making it easier to identify patterns, relationships, and correlations between them. Pairplots can help visualize the distribution of data, identify outliers, and inform further analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Based on our analysis, we observed that:
#
# The majority of paid apps have an average rating of around 4.
#
# There is a positive correlation between the number of installs and the number of reviews, which means that as the number of installations increases, the number of reviews for the app also tends to increase.

# %% [markdown]
# # **SENTIMENT ANALYSIS**

# %% [markdown]
# ## Dataset First View

# %%
df2.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
df2.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %% [markdown]
# ## Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Play Store App Sentiment Analysis Dataset size")
print("Rows {} Columns {}".format(df2.shape[0], df2.shape[1]))
# Out:
# Play Store App Sentiment Analysis Dataset size
# Rows 64295 Columns 5

# %% [markdown]
# ## Dataset Information

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# ## Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df2[df2.duplicated()])
# Out:
# 33616

# %% [markdown]
# ## Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df2.isnull().sum())
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# Visualizing the missing values
# Checking Null Value by plotting Heatmap
sns.heatmap(df2.isnull(), cbar=False)

# %% [markdown]
# ## Understanding Your Variables

# %%
# Dataset Columns
df2.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe
df2.describe(include='all')
# Out:
#                         App Translated_Review Sentiment  Sentiment_Polarity  \
# count                 64295             37427     37432        37432.000000
# unique                 1074             27994         3                 NaN
# top     Angry Birds Classic              Good  Positive                 NaN
# freq                    320               247     23998                 NaN
# mean                    NaN               NaN       NaN            0.182146
# std                     NaN               NaN       NaN            0.351301
# min                     NaN               NaN       NaN           -1.000000
# 25%                     NaN               NaN       NaN            0.000000
# 50%                     NaN               NaN       NaN            0.150000
# 75%                     NaN               NaN       NaN            0.400000
# max                     NaN               NaN       NaN            1.000000
#
#         Sentiment_Subjectivity
# ...

# %% [markdown]
# ## Variables Description

# %% [markdown]
# ### **CUSTOMER REVIEW DATA**

# %% [markdown]
# This file contains the result of the sentiment analysis conducted by the dataset creator. It has 64,295 rows of data with the following columns:
#
# App : Name of the app.
#
# Translated_Review: Either the original review in English, or a translated version if the orignal review is in another language.
#
# Sentiment: The result of the sentiment analysis conducted on a review. The value is either Positive, Neutral, or Negative.
#
# Sentiment_Polarity: A value indicating the positivity or negativity of the sentiment, values range from -1 (most negative) to 1 (most positive).
#
# Sentiment_Subjectivity: A value from 0 to 1 indicating the subjectivity of the review. Lower values indicate the review is based on factual information, and higher values indicate the review is based on personal or public opinions or judgements.

# %% [markdown]
# ## Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df2.columns.tolist():
  print("No. of unique values in ",i,"is",df2[i].nunique(),".")
# Out:
# No. of unique values in  App is 1074 .
# No. of unique values in  Translated_Review is 27994 .
# No. of unique values in  Sentiment is 3 .
# No. of unique values in  Sentiment_Polarity is 5410 .
# No. of unique values in  Sentiment_Subjectivity is 4474 .

# %% [markdown]
# ## Data Wrangling

# %%
df2.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
nan_columns = []
nan_values = []

for column in df2.columns:
    nan_columns.append(column)
    nan_values.append(df2[column].isnull().sum())

fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(nan_columns, nan_values)
plt.title("Number of Nan values present in all columns")
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Number of Nan values present in all columns')

# %%
## Duplicate values in a dataset can have a negative impact on the accuracy and reliability of the analysis and results obtained.
## To ensure the accuracy and reliability of the analysis and results obtained from the dataset, we will remove all duplicate values before merging the dataset.

# %%
#Dropping duplicate values
df2= df2.drop_duplicates()

# %%
## Combine a subset of the original dataset that includes app names and types with the corresponding apps in this dataset using a merge operation.

# %%
from pandas._libs.algos import diff_2d
df2= pd.merge(df2, df[["App","Type"]] , how='inner', on="App")

# Drop null values from sentiment data
df2 = df2.dropna()

df2.shape
# Out:
# (46729, 6)

# %% [markdown]
# To obtain the app values, we perform an inner join on the Play Store app reviews dataset with the app and type columns of the other dataset. Next, we remove any missing values from the sentiment data.

# %% [markdown]
# ## Data Vizualization

# %% [markdown]
# ### **Free vs Paid**

# %%
### Now that we have our DataFrame with the relevant data for our analysis, let's examine the distribution of app types by counting the number of apps in each category.

# %%
(values,counts)= np.unique(df2["Type"], return_counts=True)
print(counts)
for index in range(len(values)):
    print(f"{values[index]}: {counts[index]}")
# Out:
# [46209   520]
# Free: 46209
# Paid: 520

# %%
# create a dataframe for each app type
free_apps = df2[df2["Type"] == "Free"]
paid_apps = df2[df2["Type"] == "Paid"]

# %%
# Return normalized values (percentages) of each value's occurrence & display them
print("Free Apps - Sentiment Percentage \n" + "-"*30 + "\n{}\n\n".format(free_apps['Sentiment'].value_counts(normalize=True) * 100))
print("Paid Apps - Sentiment Percentage \n" + "-"*30 +"\n{}".format(paid_apps['Sentiment'].value_counts(normalize=True) * 100))
# Out:
# Free Apps - Sentiment Percentage
# ------------------------------
# Positive    63.678071
# Negative    23.590643
# Neutral     12.731286
# Name: Sentiment, dtype: float64
#
#
# Paid Apps - Sentiment Percentage
# ------------------------------
# Positive    78.076923
# Negative    15.769231
# Neutral      6.153846
# Name: Sentiment, dtype: float64

# %%
# Reset index, then drop the old index column when it is moved to the right as a new column
paid_apps = paid_apps.reset_index().drop(columns=["index"])
free_apps = free_apps.reset_index().drop(columns=["index"])

# Generate a list of random indexes applicable to free_apps
random_indexes = np.random.choice(len(free_apps)-1, len(paid_apps), replace=False)

# Shorten free_apps to the same size of paid_apps & using a random selection
free_apps = free_apps.iloc[random_indexes]

# Reset index of free_apps
free_apps = free_apps.reset_index().drop(columns=["index"])

# %%
# Generate values & counts for Sentiment columns in our dataframes & put them in dictionaries
val_ct_free = np.unique(free_apps['Sentiment'],return_counts=True)
free_data = {value: count for value, count in zip(val_ct_free[0],val_ct_free[1])}

val_ct_paid = np.unique(paid_apps['Sentiment'],return_counts=True)
paid_data = {value: count for value, count in zip(val_ct_paid[0],val_ct_paid[1])}


# Put values and counts each in a different variable for use in plots, taken from dictionaries
free_names = list(free_data.keys())
free_values = list(free_data.values())
paid_names = list(paid_data.keys())
paid_values = list(paid_data.values())


# Create a figure containing plots for each app type, sharing the y-axis for comparison
fig, axs = plt.subplots(1, 2, figsize=(10, 6),sharey=True)
axs[0].bar(free_names, free_values)
axs[0].set_title("Free App Sentiments")
axs[1].bar(paid_names, paid_values)
axs[1].set_title("Paid App Sentiments")
plt.show()

# %% [markdown]
# #### Will the gained insights help creating a positive business impact?

# %% [markdown]
# The proportion of positive sentiments in paid apps is significantly greater than that in free apps.
#
# A business can leverage the fact that paid apps have a higher percentage of positive sentiments to justify a higher price point for their app and highlight its higher perceived value compared to free alternatives. However, the decision to charge for an app should also consider factors such as target audience and market demand as it may limit the potential user base. This information can also guide marketing and promotion efforts, by emphasizing the positive sentiments associated with paid apps to attract users who are more likely to have a positive experience.

# %% [markdown]
# ### **Sentiment Polarity**

# %%
polarity_paid = paid_apps["Sentiment_Polarity"]
polarity_free = free_apps["Sentiment_Polarity"]

# Plot two histograms showing sentiment polarity of each app type
plt.figure(figsize=(14,5))
plt.hist(polarity_paid,  color="green",alpha=.7, label="Paid Apps") 
plt.hist(polarity_free, color="red",alpha=.4, label="Free Apps")

plt.title('Sentiment Polarity Distribution For Free & Paid Apps')
plt.xlabel('Sentiment Polarity')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Upon examination of the graph, it can be observed that free apps have a higher proportion of neutral polarity, as evidenced by the larger red region located just above the 0.00 mark on the x-axis.
#
# On the other hand, the graph reveals a higher concentration of free apps with extremely positive polarity, evident from the taller bars in the 0.5 to 1.00 range of the x axis.
#
# The distribution of sentiments for Paid apps shows that most opinions fall in the range of 0 to 0.5, indicating a neutral to slightly positive sentiment towards these apps.
#
# Paid apps exhibit a higher overall satisfaction, as no sentiment falls below -0.5, while some sentiments are exceptionally positive. This suggests that there is a minimum cap for negative sentiments in paid apps, and points to a higher level of customer satisfaction overall.

# %% [markdown]
# ### **Sentiment Analysis with Category**

# %%
# First we merge the Category & App of 1st data set to App column in 2nd data set
category_df = pd.merge(df2, df[["App","Category"]] , how='inner', on="App")

# Drop all nan values
category_df =category_df.dropna()

# %%
from matplotlib.ticker import PercentFormatter

# %%
f = plt.figure(figsize=(15,8))
ax = f.add_subplot(1,1,1)

sns.histplot(
    category_df,
    x="Category", hue="Sentiment",
    bins=34,
    ax=ax, 
    stat="count",
    multiple="stack",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.5,
    legend=True
    )


ax.set_title("Sentiment Analysis Based on Category",fontsize=15,fontweight='bold')
plt.xticks(rotation='vertical')
ax.set_xlabel("Category",fontsize=13)
ax.set_ylabel("Review Counts",fontsize=13)

plt.gca().yaxis.set_major_formatter(PercentFormatter(20000))
sns.set(style="ticks")
plt.grid()
plt.show()

# %% [markdown]
# The categories of Family, Sports, and Health & Fitness demonstrate the strongest performance, with more than 50% of the reviews being positive for the apps in these categories.

# %% [markdown]
# ### Will the gained insights help creating a positive business impact?

# %% [markdown]
# This information can be used in a business by focusing on developing or promoting apps in the other categories. By targeting these categories, a company may be able to benefit from the high demand for such apps and increase their chances of receiving positive reviews, leading to higher user engagement and potential revenue. Additionally, understanding the market trends and user preferences can inform product development strategies and marketing campaigns.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Business objectives are essential statements that define a company's goals and priorities. They typically relate to critical aspects of the business, including revenue, operations, productivity, and growth, that determine the company's success. To maximize success, some organizations use SMART (Specific, Measurable, Achievable, Relevant, and Time-bound) criteria when creating business objectives. Developing written business objectives can be beneficial for companies of all sizes, as they provide a clear direction and purpose for the organization and help align all team members towards achieving common goals.
#
# The aim of this analysis project is to assist the client in attaining success in the play store by offering them useful insights and recommendations. The main focus should be on developing apps in unexplored categories, providing free content to a broader audience, regularly updating the app to meet evolving user preferences, and taking user feedback into account to improve the app's functionality. By implementing these strategies, the client can boost their likelihood of achieving high installations and fulfilling their business objectives.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1.The average rating of active apps on the Google Play Store is 4.3, indicating a relatively high level of satisfaction among users.
#
# 2.Market research suggests that users tend to prefer paid apps that are lightweight and don't take up too much space on their devices. As a result, paid apps that are too large in size may struggle to perform well in the market.
#
#
# 3.The sweet spot for top-rated apps in terms of size is between approximately 2MB and 40MB, striking a balance between being neither too light nor too heavy.
#
# 4.Top-rated apps are optimally priced between $1 and $20, striking a balance between being neither too cheap nor too expensive..
#
# 5.Medical and Family apps tend to be priced higher compared to other categories, and some apps in these categories may be priced up to 80$.
#
# 6.The number of app downloads is positively correlated with the number of reviews it has received. Users are more likely to download an app that has been reviewed by a large number of people.
#
# 7.While both paid and free apps receive favorable reviews, paid apps tend to have a slightly higher proportion of favorable reviews compared to free apps.
#
# 8.Free apps tend to receive a wider range of opinions, including more negative and neutral feedback, than paid apps, which may be due to their wider availability and larger user base.
#
# 9.When it comes to user reviews, free apps tend to receive more negative feedback compared to paid apps, suggesting a higher level of criticism and lower overall satisfaction among users.
#
# 10.More than 50% of users rate Family, Sports, and Health & Fitness apps positively, while apps in the Games and Social Media categories receive mixed reviews with 50% positive and 50% negative feedback.
#
# 11.The proportion of positive sentiments in paid apps is notably greater than that in free apps.
#
# After conducting Exploratory Data Analysis (EDA) on the Google Playstore data, we gained valuable insights into the app market. Our analysis revealed patterns and trends, including the prevalence of Family and Games categories with the highest number of apps, and the average rating of apps around 4.3, indicating high user satisfaction. We also found that free apps had more installs than paid apps, suggesting a potential opportunity for businesses to expand their user base by offering free content. These insights can assist app developers, businesses, and users searching for apps to download. Overall, our EDA provided informative results and highlighted significant trends in the app market.
#
# In conclusion, the Exploratory Data Analysis (EDA) on sentiment analysis of Google Playstore data yielded valuable insights into customer feedback on apps. The analysis provided an overview of the overall sentiment of customer reviews, with a majority of reviews having a positive sentiment. Additionally, we explored the relationship between the sentiment of customer reviews and the rating of the app, and found a positive correlation between the two. These findings can provide app developers and businesses with useful information to improve their apps and enhance customer satisfaction. Overall, the EDA on sentiment analysis of the Google Playstore data was an informative exercise that revealed important trends in customer feedback on apps.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
